# %% [markdown]
# # Query code on PubMED

# %% [markdown]
# Query I am using:
#
# ((machine learning[MeSH Terms] OR natural language processing[MeSH Terms] OR phenotype[MeSH Terms])
#
# AND (electronic health records[MeSH Terms] OR electronic medical records[MeSH Terms]))

# %% [markdown]
# I found that no results with keywords: "Phenotypic", "Phenotyping", "EHR", "EMR"

# %% [markdown]
# # Step 1: Merge abstract with other basic information of these papers

# %% [markdown]
# File saved as 'new_machine_result.csv'

# %%
import re

with open('abstract-machinelea-set.txt') as f:
    i = 1
    flag = False
    abstract_abs = []
    abstract_tmp = []
    write_abstract = False
    
    PMID_abs = []
    
    for index, line in enumerate(f):
        if (write_abstract):
            flag = False
            if (not bool(line.strip())): 
                write_abstract = False 
                abstract_abs.append(' '.join(abstract_tmp))
                abstract_tmp = []
                continue 
            else: 
                abstract_tmp.append(line)
                #print(abstract_tmp)
        

        if (line[:1] in '0123456789'):
            if (int(re.search('^[0-9]+', line).group()) == i):
                #print(line)
                i = i + 1
                space_count = 0
                flag = True
                
        if (flag):
            if (not bool(line.strip())):
                space_count = space_count + 1
                #print(space_count, flag)
            
            if (space_count == 4):
                write_abstract = True
                #print(write_abstract)   
                
        ##################################
        if (line[:4] == "PMID"):
            PMID_abs.append(re.findall(r'\d+', line)[0])
            
    #print(abstract_abs[0])

# %% [markdown]
# There are total 1761 paper.

# %%
len(PMID_abs)
len(abstract_abs)
# Out:
# 1761

# %%
import pandas as pd
df = pd.read_csv('csv-machinelea-set.csv')
#df.head()

# %%
merge_abs = pd.DataFrame({'PMID':PMID_abs, 'abstract':abstract_abs})
#merge_abs.head()

# %%
df['PMID'] = df['PMID'].apply(int)
merge_abs['PMID'] = merge_abs['PMID'].apply(int)

result = pd.merge(df, merge_abs, how='inner', on=['PMID'])
#result.head()

# %%
#result.to_csv('new_machine_result.csv', index = False)

# %% [markdown]
# # Step 2: Elementory analysis for total 1761 papers

# %%
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %% [markdown]
# Total 330 journals/books have published the related paper.

# %%
journal = result.groupby("Journal/Book")

len(journal)
# Out:
# 330

# %%
plt.figure(figsize=(15,10))
s = journal.size()

s[s > 2].sort_values(ascending=False).plot.bar()
plt.xticks()
plt.xlabel("Journal or books")
plt.ylabel("Number of Paper")
plt.show()

# %% [markdown]
# There are 74 journals/books/conference with 2+ related paper.

# %%
len(s[s>2])
# Out:
# 74

# %% [markdown]
# There are 205 paper from JAMIA. 54 from PLos One and 166 from Journal of Biomedical informatics.

# %%
print(s['J Am Med Inform Assoc'])
print(s['PLoS One'])
print(s['J Biomed Inform'])
# Out:
# 205
# 54
# 166

# %%
s.sort_values(ascending=False).head(10)
# Out:
# Journal/Book
# Stud Health Technol Inform     288
# J Am Med Inform Assoc          205
# J Biomed Inform                166
# AMIA Annu Symp Proc            156
# BMC Med Inform Decis Mak        85
# PLoS One                        54
# Int J Med Inform                50
# Sci Rep                         22
# Artif Intell Med                20
# IEEE J Biomed Health Inform     19
# dtype: int64

# %%
year = result.groupby("Publication Year")

year.size()
# Out:
# Publication Year
# 2008      2
# 2009     15
# 2010     40
# 2011     60
# 2012     63
# 2013    132
# 2014    135
# 2015    201
# 2016    133
# 2017    155
# 2018    247
# 2019    376
# 2020    193
# 2021      9
# dtype: int64

# %%
text = " ".join(review for review in result.abstract)
print ("There are {} words in the combination of all review.".format(len(text)))

# Create stopword list:
stopwords = set(STOPWORDS)
stopwords.update(["used", "data"])



# genearte word cloud
wordcloud = WordCloud(width = 3000, height = 2000, random_state=1, 
                      collocations=False, stopwords = stopwords, 
                      background_color='salmon', colormap='Pastel1').generate(text)


#wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")

fig.savefig('word_cloud.svg', format='svg', dpi=1200)
plt.show()
# Out:
# There are 2348067 words in the combination of all review.

# %%
result.head()
# Out:
#        PMID                                              Title  \
# 0  30617335             A guide to deep learning in healthcare
# 1  29126825  Artificial Intelligence in Medical Practice: T...
# 2  31706869  Artificial Intelligence and Machine Learning i...
# 3  28729030  Natural language processing systems for captur...
# 4  30742121  Evaluation and accurate diagnoses of pediatric...
#
#                                              Authors  \
# 0  Esteva A, Robicquet A, Ramsundar B, Kuleshov V...
# 1                               Miller DD, Brown EW.
# 2                                           Kilic A.
# 3  Kreimeyer K, Foster M, Pandey A, Arya N, Halfo...
# 4  Liang H, Tsui BY, Ni H, Valentim CCS, Baxter S...
#
#                                             Citation First Author  \
# 0  Nat Med. 2019 Jan;25(1):24-29. doi: 10.1038/s4...     Esteva A
# 1  Am J Med. 2018 Feb;131(2):129-133. doi: 10.101...    Miller DD
# 2  Ann Thorac Surg. 2020 May;109(5):1323-1329. do...      Kilic A
# 3  J Biomed Inform. 2017 Sep;73:14-29. doi: 10.10...  Kreimeyer K
# 4  Nat Med. 2019 Mar;25(3):433-438. doi: 10.1038/...      Liang H
#
#       Journal/Book  Publication Year Create Date       PMCID      NIHMS ID  \
# 0          Nat Med              2019  2019-01-09         NaN           NaN
# 1         Am J Med              2018  2017-11-12         NaN           NaN
# 2  Ann Thorac Surg              2020  2019-11-11         NaN           NaN
# 3  J Biomed Inform              2017  2017-07-22  PMC6864736  NIHMS1053356
# 4          Nat Med              2019  2019-02-12         NaN           NaN
#
#                                 DOI  \
# 0         10.1038/s41591-018-0316-z
# 1      10.1016/j.amjmed.2017.10.035
# 2  10.1016/j.athoracsur.2019.09.042
# 3         10.1016/j.jbi.2017.07.012
# 4         10.1038/s41591-018-0335-9
#
#                                             abstract
# 0  Here we present deep-learning techniques for h...
# 1  Computer science advances and ultra-fast compu...
# 2  BACKGROUND: This review article provides an ov...
# 3  We followed a systematic approach based on the...
# 4  Artificial intelligence (AI)-based methods hav...
